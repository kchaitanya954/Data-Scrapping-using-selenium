# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('moooi.xlsx')
df
# Out:
#                                  name  \
# 0                          Amami Pouf
# 1                          Amami Pouf
# 2                          Amami Pouf
# 3                          Amami Pouf
# 4                          Amami Pouf
# ...                               ...
# 2985  Zio Lounge Chair with Footstool
# 2986  Zio Lounge Chair with Footstool
# 2987  Zio Lounge Chair with Footstool
# 2988  Zio Lounge Chair with Footstool
# 2989  Zio Lounge Chair with Footstool
#
#                                                     sku           GTIN  \
# 0                                         8718282343600  8718282343600
# 1                                         8718282343617  8718282343617
# 2                                         8718282343594  8718282343594
# 3                                         8718282343631  8718282343631
# 4                                         8718282343648  8718282343648
# ...                                                 ...            ...
# ...

# %%
for i in range(len(df)):
    try:
        if 'google' in df['hero_image'][i]:
            hero_img_id = df['hero_image'][i].split('/')[-2]
            df['hero_image'][i] = f'https://drive.google.com/file/d/{hero_img_id}/view'
            print(df['hero_image'][i])
    except:
        pass
    
    try:
        if 'google' in df['variant_image'][i]:
            var_img_id = df['variant_image'][i].split('/')[-2]
            df['variant_image'][i] =  f'https://drive.google.com/file/d/{var_img_id}/view'
            print(df['variant_image'][i])
    except:
        pass
    images = df['images'][i].split('\n')
    google_img = [img for img in images if 'google' in img]
    rem_images = [rimg for rimg in images if 'google' not in rimg]
    google_imgs = [f'https://drive.google.com/file/d/{gimg.split("/")[-2]}/view' for gimg in google_img]
    all_images = '\n'.join(google_imgs + rem_images)
    df['images'][i] = all_images
# Out:
# C:\Users\CHAITA~1\AppData\Local\Temp/ipykernel_4884/1922913116.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['images'][i] = all_images
# C:\Users\CHAITA~1\AppData\Local\Temp/ipykernel_4884/1922913116.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['variant_image'][i] =  f'https://drive.google.com/file/d/{var_img_id}/view'
# C:\Users\CHAITA~1\AppData\Local\Temp/ipykernel_4884/1922913116.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['hero_image'][15].split('/')[-2]
# Out:
# '122YLQrwQfnZa9I8DcFb5dOkV7HiDQ5V0'

# %%
k = df['images'][20].split('\n')
k
# Out:
# ['https://docs.google.com/uc?id=14N8pB7GdyCBbmF2GqAjwsK654RQymTcp&key=AIzaSyDM3kTrvLy3yKpRHZKrpGvRs7PbxEi_ET4',
#  'https://cdn.moooi.com/tmp/image-thumbnails/Collection/Bart/Bart%20Swivel/image-thumb__37404__width_1200/Bart-Swivel-Blushing-Sloth-Wooly.png',
#  'https://cdn.moooi.com/tmp/image-thumbnails/Collection/Bart/Bart%20Swivel/image-thumb__16222__story_splitscreen_2x_jpg/Bart_Swivel_Cervino_Cognac_Detail.jpg',
#  'https://cdn.moooi.com/tmp/image-thumbnails/Collection/Bart/Bart%20Swivel/image-thumb__16221__story_splitscreen_2x_jpg/Bart_Swivel_Cervino_Mud_556.jpg',
#  'https://cdn.moooi.com/tmp/image-thumbnails/Applied/Haikus/image-thumb__16111__story_splitscreen_2x_jpg/301019Haiku__BartArmchair.jpg',
#  'https://cdn.moooi.com/tmp/image-thumbnails/Collection/Bart/Bart%20Swivel/image-thumb__30074__width_1200/Bart-Armchair-Shade-Ochre-detail-02.png',
# ...

# %%
df.to_csv('moooi.csv')

# %%
from __future__ import print_function

import io

import google.auth
import googleapiclient
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from googleapiclient.http import MediaIoBaseDownload
import google-api-core


def download_file(real_file_id):
    """Downloads a file
    Args:
        real_file_id: ID of the file to download
    Returns : IO object with location.

    Load pre-authorized user credentials from the environment.
    TODO(developer) - See  
    for guides on implementing OAuth2 for the application.
    """
    creds, _ = google.auth.default()

    try:
        # create drive api client
        service = build('drive', 'v3', credentials=creds)

        file_id = real_file_id

        # pylint: disable=maybe-no-member
        request = service.files().get_media(fileId=file_id)
        file = io.BytesIO()
        downloader = MediaIoBaseDownload(file, request)
        done = False
        while done is False:
            status, done = downloader.next_chunk()
            print(F'Download {int(status.progress() * 100)}.')

    except HttpError as error:
        print(F'An error occurred: {error}')
        file = None

    return file.getvalue()


if __name__ == '__main__':
    download_file(real_file_id='1KuPmvGq8yoYgbfW74OENMCB5H0n_2Jm9')
# Out:
#   File "C:\Users\CHAITA~1\AppData\Local\Temp/ipykernel_18848/3092633268.py", line 10
#     import google-api-core
#                  ^
# SyntaxError: invalid syntax

# %%
# !pip install google-api-core
